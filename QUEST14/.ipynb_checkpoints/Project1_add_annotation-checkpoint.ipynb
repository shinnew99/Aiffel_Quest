# %% [markdown]
# ## 14-1. 프로젝트 : Segmentation map으로 도로 이미지 만들기
#
# 데이터셋을 이용해 Pix2Pix를 학습시켜보기</br>
#
# - [cityscapes.zip](https://d3s0tskafalll9.cloudfront.net/media/documents/cityscapes.zip)
#
# **프로젝트 수행**
#
# ---
#
# 프로젝트를 진행하면서 필수로 수행해야 할 사항은 다음과 같다.</br>
#
#     1. 데이터에 한 가지 이상의 **augmentation 방법**을 적용하여 학습해 주세요.</br>
#     (어떠한 방법을 사용했는지 적어주세요.)
#     2. 이전에 구현했던 두 개의 Generator 중 Encoder와 Decoder간에 skip connection이 있는 **U-Net Generator를 사용**해 주세요.
#     3. 모델 학습 후, 학습된 Generator를 이용해 테스트합니다. 테스트 데이터는 다운로드했던 "val" 폴더 내 이미지를 사용해 주세요.
#     4. 1개 이상의 이미지에 대해 테스트 과정을 거친 후 그 결과를 **스케치, 생성된 사진, 실제 사진 순서로 나란히 시각화**해 주세요.
#     5. 모델을 충분히 학습하기에 시간이 부족할 수 있습니다. 적어도 10 epoch 이상 학습하며 **중간 손실 값에 대한 로그**를 남겨주세요. 좋은 결과를 얻기 위해선 긴 학습 시간이 필요하므로 테스트 결과는 만족스럽지 않아도 괜찮습니다.

# %% [markdown]
# 아래의 기준을 바탕으로 프로젝트를 평가합니다.</br>
#
# <table>
#     <tr>
#         <td><b>평가문항</b></td>
#         <td><b>상세기준</b></td>
#     </tr>
#     <tr>
#         <td>1. pix2pix 모델 학습을 위해 필요한 데이터셋을 적절히 구축하였다.</td>
#         <td>데이터 분석 과정 및 한 가지 이상의 augmentation을 포함한 데이터셋 구축 과정이 체계적으로 제시되었다.</td>
#     </tr>
#     <tr>
#         <td>2. pix2pix 모델을 구현하여 성공적으로 학습 과정을 진행하였다.</td>
#         <td>U-Net generator, discriminator 모델 구현이 완료되어 train_step의 output을 확인하고 개선하였다.</td>
#     </tr>
#     <tr>
#         <td>3. 학습 과정 및 테스트에 대한 시각화 결과를 제출하였다.</td>
#         <td>10 epoch 이상의 학습을 진행한 후 최종 테스트 결과에서 진행한 epoch 수에 걸맞은 저오의 품질을 확인하였다.</td>
#     </tr>
# </table>

# %%
# 모듈 임포트
import tensorflow as tf
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
from tensorflow import image
from tensorflow.keras.preprocessing.image import random_rotation
from tensorflow import data
from tensorflow.keras import layers, Input, Model

from tensorflow.keras import losses
from tensorflow.keras import optimizers

import os
import pathlib

# %%
# 파일 다운로드
_URL = "https://d3s0tskafalll9.cloudfront.net/media/documents/cityscapes.zip"
dataset_name = "cityscapes"

# tf.keras.utils.get_file()
# URL에서 파일 정보 가져와서 $HOME/.keras/datasets/target_file.zip 위치에 cache로 저장
path_to_zip = tf.keras.utils.get_file(
    fname=f"{dataset_name}.tar.gz",
    origin=_URL,
    extract=True)

path_to_zip  = pathlib.Path(path_to_zip)

PATH = path_to_zip.parent/dataset_name

# %%
# 데이터 1장씩 확인(train, val)
train_path = os.path.join(str(PATH), "train/")
val_path = os.path.join(str(PATH), "val/")

f = train_path + os.listdir(train_path)[1]
img = cv2.imread(f, cv2.IMREAD_COLOR)

plt.imshow(img)

# %%
# 이미지 전처리를 위한 함수 선언
# input_image, real_image를 데이터셋(f)에서 획득
## denormalize() 함수 사용하여 나온 결과 확인
def normalize(x):
    x = tf.cast(x, tf.float32)
    return (x/127.5) - 1

def denormalize(x):
    x = (x+1)*127.5
    x = x.numpy()
    return x.astype(np.uint8)

def load_img(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, 3)
    
    w = tf.shape(img)[1] // 2
    sketch = img[:, :w, :] 
    sketch = tf.cast(sketch, tf.float32)
    colored = img[:, w:, :] 
    colored = tf.cast(colored, tf.float32)
    return normalize(sketch), normalize(colored)

f = train_path + os.listdir(train_path)[1]
sketch, colored = load_img(f)

plt.figure(figsize=(10,7))
plt.subplot(1,2,1); plt.imshow(denormalize(sketch))
plt.subplot(1,2,2); plt.imshow(denormalize(colored))

# %%
# Augmentation 적용
@tf.function()  # 빠른 텐서플로 연산을 위해 @tf.function()을 사용합니다.
def apply_augmentation(sketch, colored):
    # 이미지 합치기; 3채널의 이미지 두 개를 6채널의 이미지 하나로 합침
    stacked = tf.concat([sketch, colored], axis=-1)
    
    _pad = tf.constant([[30,30],[30,30],[0,0]])
    if tf.random.uniform(()) < .5:
        padded = tf.pad(stacked, _pad, "REFLECT")
    else:
        padded = tf.pad(stacked, _pad, "CONSTANT", constant_values=1.)
    # 50% 미만의 확률로 (if 부분) Reflection padding 적용
    # 반대의 경우엔 Constant padding 적용
    ## 위 두 내역은 padded에 반영됨

    # 이미지를 랜덤하게 자름(crop)
    out = image.random_crop(padded, size=[256, 256, 6])
    # 이미지를 좌우반전시킴
    out = image.random_flip_left_right(out)
    # 이미지를 상하반전시킴
    out = image.random_flip_up_down(out)
    
    if tf.random.uniform(()) < .5:
        # 이미지를 50% 미만 확률로 회전시킴(image.rot90)
        # k 인자는 회전 시 몇번 회전하였는가를 결정함
        degree = tf.random.uniform([], minval=1, maxval=4, dtype=tf.int32)
        out = image.rot90(out, k=degree)
    
    return out[...,:3], out[...,3:]

# %%
# 이미지를 불러 `load_img()` Augmentation을 적용 시킨 후 sketch, colored 이미지를 반환하는 함수 선언
def get_img(img_path):
    sketch, colored = load_img(img_path)
    sketch, colored = apply_augmentation(sketch, colored)
    return sketch, colored

# %%
# 훈련 데이터셋의 이미지를 나누고 augmentation 적용
train_images = data.Dataset.list_files(train_path + "*.jpg")
train_images = train_images.map(get_img).shuffle(100).batch(4)

# %%
# U-Net Generator 구성을 위한 Blocks 설정

# Encode-block 설정
class EncodeBlock(layers.Layer):
    def __init__(self, n_filters, use_bn=True):
        super(EncodeBlock, self).__init__()
        self.use_bn = use_bn       
        self.conv = layers.Conv2D(n_filters, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.lrelu = layers.LeakyReLU(0.2)

    def call(self, x):
        x = self.conv(x)
        if self.use_bn:
            x = self.batchnorm(x)
        return self.lrelu(x)

# Decode-block 설정    
class DecodeBlock(layers.Layer):
    def __init__(self, f, dropout=True):
        super(DecodeBlock, self).__init__()
        self.dropout = dropout
        self.Transconv = layers.Conv2DTranspose(f, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.relu = layers.ReLU()
        
    def call(self, x):
        x = self.Transconv(x)
        x = self.batchnorm(x)
        if self.dropout:
            x = layers.Dropout(.5)(x)
        return self.relu(x)

# %%
# 위에서 선언한 Block 들을 활용하여 U-Net Generator 구성
class UNetGenerator(Model):
    def __init__(self):
        super(UNetGenerator, self).__init__()
        encode_filters = [64,128,256,512,512,512,512,512]
        decode_filters = [512,512,512,512,256,128,64]
        
        self.encode_blocks = []
        for i, f in enumerate(encode_filters):
            if i == 0:
                self.encode_blocks.append(EncodeBlock(f, use_bn=False))
            else:
                self.encode_blocks.append(EncodeBlock(f))
        
        self.decode_blocks = []
        for i, f in enumerate(decode_filters):
            if i < 3:
                self.decode_blocks.append(DecodeBlock(f))
            else:
                self.decode_blocks.append(DecodeBlock(f, dropout=False))
        
        self.last_conv = layers.Conv2DTranspose(3, 4, 2, "same", use_bias=False)
    
    def call(self, x):
        features = []
        for block in self.encode_blocks:
            x = block(x)
            features.append(x)
        
        features = features[:-1]
                    
        for block, feat in zip(self.decode_blocks, features[::-1]):
            x = block(x)
            x = layers.Concatenate()([x, feat])
        
        x = self.last_conv(x)
        return x
                
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()

# %%
# Discriminator 구성을 위한 DiscBlock 선언
class DiscBlock(layers.Layer):
    def __init__(self, n_filters, stride=2, custom_pad=False, use_bn=True, act=True):
        super(DiscBlock, self).__init__()
        self.custom_pad = custom_pad
        self.use_bn = use_bn
        self.act = act
        
        if custom_pad:
            self.padding = layers.ZeroPadding2D()
            self.conv = layers.Conv2D(n_filters, 4, stride, "valid", use_bias=False)
        else:
            self.conv = layers.Conv2D(n_filters, 4, stride, "same", use_bias=False)
        
        self.batchnorm = layers.BatchNormalization() if use_bn else None
        self.lrelu = layers.LeakyReLU(0.2) if act else None
        
    def call(self, x):
        if self.custom_pad:
            x = self.padding(x)
            x = self.conv(x)
        else:
            x = self.conv(x)
                
        if self.use_bn:
            x = self.batchnorm(x)
            
        if self.act:
            x = self.lrelu(x)
        return x

# %%
# DiscBlock()을 이용하여 Discriminator 클래스 선언
## 내부 인코딩(Block append)은 for문으로 구현
class Discriminator(Model):
    def __init__(self):
        super(Discriminator, self).__init__()
        
        filters = [64,128,256,512,1]
        self.blocks = [layers.Concatenate()]
        # For문을 활용해서 DiscBlock을 쌓아주세요.

        # DiscBlock에 필요한 arguments 초기값 설정
        n_filters, stride = None, None  # type setting as int, int
        custom_pad, use_bn, act = None, None, None # type setting as Bool, Bool, Bool

        for idx_of_filters in range(len(filters)):
            # 조건 1 : 3번째까지 stride는 2로 주되 이후에는 1로 주세요
            # 조건 2 : 3번째까지 custom padding을 주지 않아도 되는데 이후에는 주세요.
            if idx_of_filters < 3:
                stride = 2
                custom_pad = False
            else:
                stride = 1
                custom_pad = True
            # 조건 3: 1번째와 5번째에서는 Batch Normalization을 사용하지 마세요.    
            if idx_of_filters == 0 or idx_of_filters == 4:
                use_bn = False
            else:
                use_bn = True
            # 조건 4 : 1번째부터 4번째까지 LeakyReLU를 적용하고 마지막에는 sigmoid를 적용하세요.
            if idx_of_filters <= 3:
                act = True
            else:
                act = False
            
            # flters 순서대로 n_filters의 값을 적용; 조건과 무관함
            n_filters = filters[idx_of_filters]

            # DiscBlock() appending; self.blocks의 길이를 늘리자
            self.blocks.append(DiscBlock(n_filters=n_filters, stride=stride, 
                    custom_pad=custom_pad, use_bn=use_bn, act=act))

        ## (sigmoid의 경우 따로 정의해야 합니다)
        self.sigmoid = layers.Activation("sigmoid")
    
    def call(self, x, y):
        # Block 통과한 출력값 out 초기화
        out = None
        # __init__()에서 쌓은 blocks를 local var로 가져와보자
        blocks = self.blocks

        # list인 blocks를 순회
        for idx_of_blocks in range(len(blocks)):
            if idx_of_blocks == 0:
                # blocks[0] == layers.Concatenate()
                out = blocks[idx_of_blocks]([x, y])
            else:
                out = blocks[idx_of_blocks](out)
        
        return self.sigmoid(out)
    
    def get_summary(self, x_shape=(256,256,3), y_shape=(256,256,3)):
        x, y = Input(x_shape), Input(y_shape) 
        return Model((x, y), self.call(x, y)).summary()

# %%
# 256 x 256 RGB 이미지 랜덤생성 해서 Discriminator 적용
# imshow()를 통해 적용된 이미지 확인
x = tf.random.normal([1,256,256,3])
y = tf.random.uniform([1,256,256,3])

disc_out = Discriminator()(x, y)
plt.imshow(disc_out[0, ... ,0])
plt.colorbar()

# %%
# 손실함수 선언
# GAN loss와 L1 loss가 둘다 적용된 것이 논문에서 결과가 좋아서 이렇게 생성하였음
bce = losses.BinaryCrossentropy(from_logits=False)
mae = losses.MeanAbsoluteError()

def get_gene_loss(fake_output, real_output, fake_disc):
    l1_loss = mae(real_output, fake_output)
    gene_loss = bce(tf.ones_like(fake_disc), fake_disc)
    return gene_loss, l1_loss

def get_disc_loss(fake_disc, real_disc):
    return bce(tf.zeros_like(fake_disc), fake_disc) + bce(tf.ones_like(real_disc), real_disc)

# %%
# Optimizer 선언
gene_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)
disc_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)

# %%
# 하나의 배치가 입력되면 가중치를 1회 업데이트하는 함수 선언
@tf.function
def train_step(sketch, real_colored):
    with tf.GradientTape() as gene_tape, tf.GradientTape() as disc_tape:
        # Generator 예측
        fake_colored = generator(sketch, training=True)
        # Discriminator 예측
        fake_disc = discriminator(sketch, fake_colored, training=True)
        real_disc = discriminator(sketch, real_colored, training=True)
        # Generator 손실 계산
        gene_loss, l1_loss = get_gene_loss(fake_colored, real_colored, fake_disc)
        # 논문 기준 L1 Loss값에 λ값을 곱하는 수식이 있음; λ = 100
        gene_total_loss = gene_loss + (100 * l1_loss) ## <===== L1 손실 반영 λ=100
        # Discrminator 손실 계산
        disc_loss = get_disc_loss(fake_disc, real_disc)
                
    gene_gradient = gene_tape.gradient(gene_total_loss, generator.trainable_variables)
    disc_gradient = disc_tape.gradient(disc_loss, discriminator.trainable_variables)
    
    gene_opt.apply_gradients(zip(gene_gradient, generator.trainable_variables))
    disc_opt.apply_gradients(zip(disc_gradient, discriminator.trainable_variables))
    return gene_loss, l1_loss, disc_loss

# %%
# 10 epoch의 학습 진행
EPOCHS = 10

generator = UNetGenerator()
discriminator = Discriminator()
history = {'gen_loss':[], 'l1_loss':[], 'disc_loss':[]} # loss 값 시각화를 위해 생성

for epoch in range(1, EPOCHS+1):
    for i, (sketch, colored) in enumerate(train_images):
        g_loss, l1_loss, d_loss = train_step(sketch, colored)
        history['gen_loss'].append(g_loss)
        history['l1_loss'].append(l1_loss)
        history['disc_loss'].append(d_loss)      
            
            
        # 10회 반복마다 손실을 출력합니다.
        if (i+1) % 10 == 0:
            print(f"EPOCH[{epoch}] - STEP[{i+1}] \
                    \nGenerator_loss:{g_loss.numpy():.4f} \
                    \nL1_loss:{l1_loss.numpy():.4f} \
                    \nDiscriminator_loss:{d_loss.numpy():.4f}", end="\n\n")
# Out:
# EPOCH[1] - STEP[10]
# Generator_loss:0.8307
# L1_loss:0.3474
# Discriminator_loss:1.2664
#
# EPOCH[1] - STEP[20]
# Generator_loss:0.9058
# L1_loss:0.3015
# Discriminator_loss:1.1755
#
# EPOCH[1] - STEP[30]
# Generator_loss:1.0739
# L1_loss:0.2952
# Discriminator_loss:0.9146
#
# EPOCH[1] - STEP[40]
# Generator_loss:1.4190
# L1_loss:0.2632
# Discriminator_loss:0.7377
#
# EPOCH[1] - STEP[50]
# Generator_loss:1.6171
# L1_loss:0.2345
# Discriminator_loss:0.7004
#
# EPOCH[1] - STEP[60]
# Generator_loss:1.8761
# L1_loss:0.2772
# Discriminator_loss:0.6312
#
# EPOCH[1] - STEP[70]
# Generator_loss:1.5718
# L1_loss:0.2451
# Discriminator_loss:0.6449
#
# EPOCH[1] - STEP[80]
# Generator_loss:1.6280
# L1_loss:0.2043
# Discriminator_loss:0.7794
#
# EPOCH[1] - STEP[90]
# Generator_loss:2.7997
# L1_loss:0.2450
# Discriminator_loss:0.7689
#
# EPOCH[1] - STEP[100]
# Generator_loss:1.7579
# L1_loss:0.2513
# Discriminator_loss:0.5331
#
# EPOCH[1] - STEP[110]
# Generator_loss:0.4925
# L1_loss:0.2636
# Discriminator_loss:1.2848
#
# EPOCH[1] - STEP[120]
# Generator_loss:2.0096
# L1_loss:0.2352
# Discriminator_loss:0.7536
#
# EPOCH[1] - STEP[130]
# Generator_loss:0.8775
# L1_loss:0.2350
# Discriminator_loss:0.9210
#
# EPOCH[1] - STEP[140]
# Generator_loss:2.5371
# L1_loss:0.1915
# Discriminator_loss:1.2895
#
# EPOCH[1] - STEP[150]
# Generator_loss:1.6981
# L1_loss:0.2468
# Discriminator_loss:0.5626
#
# EPOCH[1] - STEP[160]
# Generator_loss:1.9328
# L1_loss:0.1954
# Discriminator_loss:0.8795
#
# EPOCH[1] - STEP[170]
# Generator_loss:2.2790
# L1_loss:0.2372
# Discriminator_loss:0.6101
#
# EPOCH[1] - STEP[180]
# Generator_loss:0.6785
# L1_loss:0.2502
# Discriminator_loss:1.0120
#
# EPOCH[1] - STEP[190]
# Generator_loss:2.3626
# L1_loss:0.2057
# Discriminator_loss:0.6665
#
# EPOCH[1] - STEP[200]
# Generator_loss:1.7334
# L1_loss:0.2087
# Discriminator_loss:0.6109
#
# EPOCH[1] - STEP[210]
# Generator_loss:2.4322
# L1_loss:0.2248
# Discriminator_loss:0.9154
#
# EPOCH[1] - STEP[220]
# Generator_loss:2.9325
# L1_loss:0.2753
# Discriminator_loss:0.2173
#
# EPOCH[1] - STEP[230]
# Generator_loss:1.2464
# L1_loss:0.2697
# Discriminator_loss:1.0809
#
# EPOCH[1] - STEP[240]
# Generator_loss:1.8924
# L1_loss:0.1916
# Discriminator_loss:1.0281
#
# EPOCH[1] - STEP[250]
# Generator_loss:1.5415
# L1_loss:0.2274
# Discriminator_loss:0.4963
#
# EPOCH[2] - STEP[10]
# Generator_loss:2.0096
# L1_loss:0.2468
# Discriminator_loss:0.5548
#
# EPOCH[2] - STEP[20]
# Generator_loss:0.9146
# L1_loss:0.2018
# Discriminator_loss:1.0089
#
# EPOCH[2] - STEP[30]
# Generator_loss:2.2263
# L1_loss:0.2242
# Discriminator_loss:0.7503
#
# EPOCH[2] - STEP[40]
# Generator_loss:2.4169
# L1_loss:0.2008
# Discriminator_loss:1.2232
#
# EPOCH[2] - STEP[50]
# Generator_loss:2.0018
# L1_loss:0.2119
# Discriminator_loss:0.5735
#
# EPOCH[2] - STEP[60]
# Generator_loss:2.2039
# L1_loss:0.2289
# Discriminator_loss:0.5461
#
# EPOCH[2] - STEP[70]
# Generator_loss:1.9687
# L1_loss:0.2580
# Discriminator_loss:0.4126
#
# EPOCH[2] - STEP[80]
# Generator_loss:1.6762
# L1_loss:0.2344
# Discriminator_loss:0.5687
#
# EPOCH[2] - STEP[90]
# Generator_loss:1.7847
# L1_loss:0.1941
# Discriminator_loss:0.7504
#
# EPOCH[2] - STEP[100]
# Generator_loss:0.7511
# L1_loss:0.2101
# Discriminator_loss:1.0929
#
# EPOCH[2] - STEP[110]
# Generator_loss:1.9925
# L1_loss:0.2280
# Discriminator_loss:0.4724
#
# EPOCH[2] - STEP[120]
# Generator_loss:0.9374
# L1_loss:0.1948
# Discriminator_loss:0.8568
#
# EPOCH[2] - STEP[130]
# Generator_loss:2.2401
# L1_loss:0.2373
# Discriminator_loss:0.4217
#
# EPOCH[2] - STEP[140]
# Generator_loss:1.8665
# L1_loss:0.1969
# Discriminator_loss:0.4003
#
# EPOCH[2] - STEP[150]
# Generator_loss:2.5368
# L1_loss:0.1724
# Discriminator_loss:0.9416
#
# EPOCH[2] - STEP[160]
# Generator_loss:1.1448
# L1_loss:0.2252
# Discriminator_loss:0.8375
#
# EPOCH[2] - STEP[170]
# Generator_loss:3.1006
# L1_loss:0.1840
# Discriminator_loss:0.5236
#
# EPOCH[2] - STEP[180]
# Generator_loss:1.9753
# L1_loss:0.2041
# Discriminator_loss:0.4607
#
# EPOCH[2] - STEP[190]
# Generator_loss:2.2169
# L1_loss:0.2122
# Discriminator_loss:2.0500
#
# EPOCH[2] - STEP[200]
# Generator_loss:1.2564
# L1_loss:0.2172
# Discriminator_loss:0.6948
#
# EPOCH[2] - STEP[210]
# Generator_loss:2.4494
# L1_loss:0.1819
# Discriminator_loss:0.4902
#
# EPOCH[2] - STEP[220]
# Generator_loss:1.7989
# L1_loss:0.2165
# Discriminator_loss:0.5054
#
# EPOCH[2] - STEP[230]
# Generator_loss:2.0296
# L1_loss:0.2219
# Discriminator_loss:0.5521
#
# EPOCH[2] - STEP[240]
# Generator_loss:2.7750
# L1_loss:0.1956
# Discriminator_loss:0.2152
#
# EPOCH[2] - STEP[250]
# Generator_loss:1.7137
# L1_loss:0.2213
# Discriminator_loss:0.4700
#
# EPOCH[3] - STEP[10]
# Generator_loss:0.3381
# L1_loss:0.2207
# Discriminator_loss:1.5609
#
# EPOCH[3] - STEP[20]
# Generator_loss:3.6059
# L1_loss:0.2195
# Discriminator_loss:0.1648
#
# EPOCH[3] - STEP[30]
# Generator_loss:1.5348
# L1_loss:0.2144
# Discriminator_loss:0.4886
#
# EPOCH[3] - STEP[40]
# Generator_loss:1.2466
# L1_loss:0.2498
# Discriminator_loss:0.7520
#
# EPOCH[3] - STEP[50]
# Generator_loss:2.7727
# L1_loss:0.2080
# Discriminator_loss:0.4181
#
# EPOCH[3] - STEP[60]
# Generator_loss:2.0342
# L1_loss:0.2288
# Discriminator_loss:0.4611
#
# EPOCH[3] - STEP[70]
# Generator_loss:2.0397
# L1_loss:0.1736
# Discriminator_loss:0.6116
#
# EPOCH[3] - STEP[80]
# Generator_loss:2.1663
# L1_loss:0.1814
# Discriminator_loss:0.6052
#
# EPOCH[3] - STEP[90]
# Generator_loss:2.7367
# L1_loss:0.2357
# Discriminator_loss:0.3581
#
# EPOCH[3] - STEP[100]
# Generator_loss:2.1731
# L1_loss:0.2061
# Discriminator_loss:0.4798
#
# EPOCH[3] - STEP[110]
# Generator_loss:0.5245
# L1_loss:0.1882
# Discriminator_loss:1.2805
#
# EPOCH[3] - STEP[120]
# Generator_loss:3.1038
# L1_loss:0.1554
# Discriminator_loss:1.2951
#
# EPOCH[3] - STEP[130]
# Generator_loss:1.8780
# L1_loss:0.1775
# Discriminator_loss:1.2085
#
# EPOCH[3] - STEP[140]
# Generator_loss:1.4446
# L1_loss:0.2030
# Discriminator_loss:0.6547
#
# EPOCH[3] - STEP[150]
# Generator_loss:1.8442
# L1_loss:0.2062
# Discriminator_loss:0.4823
#
# EPOCH[3] - STEP[160]
# Generator_loss:1.6617
# L1_loss:0.1858
# Discriminator_loss:0.6447
#
# EPOCH[3] - STEP[170]
# Generator_loss:1.1549
# L1_loss:0.1753
# Discriminator_loss:0.6399
#
# EPOCH[3] - STEP[180]
# Generator_loss:2.7762
# L1_loss:0.2177
# Discriminator_loss:1.2061
#
# EPOCH[3] - STEP[190]
# Generator_loss:1.6090
# L1_loss:0.2005
# Discriminator_loss:0.7035
#
# EPOCH[3] - STEP[200]
# Generator_loss:2.0320
# L1_loss:0.2163
# Discriminator_loss:0.4517
#
# EPOCH[3] - STEP[210]
# Generator_loss:1.6534
# L1_loss:0.1846
# Discriminator_loss:1.1196
#
# EPOCH[3] - STEP[220]
# Generator_loss:1.7214
# L1_loss:0.1931
# Discriminator_loss:0.7690
#
# EPOCH[3] - STEP[230]
# Generator_loss:2.4571
# L1_loss:0.1663
# Discriminator_loss:1.5813
#
# EPOCH[3] - STEP[240]
# Generator_loss:1.7687
# L1_loss:0.1786
# Discriminator_loss:1.0846
#
# EPOCH[3] - STEP[250]
# Generator_loss:1.4118
# L1_loss:0.1791
# Discriminator_loss:0.6946
#
# EPOCH[4] - STEP[10]
# Generator_loss:2.6273
# L1_loss:0.1632
# Discriminator_loss:1.0499
#
# EPOCH[4] - STEP[20]
# Generator_loss:2.0842
# L1_loss:0.1723
# Discriminator_loss:2.0061
#
# EPOCH[4] - STEP[30]
# Generator_loss:1.9123
# L1_loss:0.2140
# Discriminator_loss:0.4380
#
# EPOCH[4] - STEP[40]
# Generator_loss:2.0220
# L1_loss:0.1952
# Discriminator_loss:1.2313
#
# EPOCH[4] - STEP[50]
# Generator_loss:0.5119
# L1_loss:0.1952
# Discriminator_loss:1.9086
#
# EPOCH[4] - STEP[60]
# Generator_loss:1.7711
# L1_loss:0.1720
# Discriminator_loss:0.3467
#
# EPOCH[4] - STEP[70]
# Generator_loss:1.5869
# L1_loss:0.1675
# Discriminator_loss:0.6748
#
# EPOCH[4] - STEP[80]
# Generator_loss:1.4111
# L1_loss:0.1949
# Discriminator_loss:0.6511
#
# EPOCH[4] - STEP[90]
# Generator_loss:2.7118
# L1_loss:0.2098
# Discriminator_loss:0.6600
#
# EPOCH[4] - STEP[100]
# Generator_loss:2.1109
# L1_loss:0.2168
# Discriminator_loss:0.5721
#
# EPOCH[4] - STEP[110]
# Generator_loss:2.1874
# L1_loss:0.1929
# Discriminator_loss:0.5942
#
# EPOCH[4] - STEP[120]
# Generator_loss:2.1536
# L1_loss:0.2245
# Discriminator_loss:0.4282
#
# EPOCH[4] - STEP[130]
# Generator_loss:1.0885
# L1_loss:0.1952
# Discriminator_loss:0.8066
#
# EPOCH[4] - STEP[140]
# Generator_loss:1.5528
# L1_loss:0.1727
# Discriminator_loss:0.5679
#
# EPOCH[4] - STEP[150]
# Generator_loss:2.5890
# L1_loss:0.2057
# Discriminator_loss:0.2761
#
# EPOCH[4] - STEP[160]
# Generator_loss:1.9650
# L1_loss:0.1722
# Discriminator_loss:0.8544
#
# EPOCH[4] - STEP[170]
# Generator_loss:0.8916
# L1_loss:0.1982
# Discriminator_loss:1.0378
#
# EPOCH[4] - STEP[180]
# Generator_loss:1.4150
# L1_loss:0.1863
# Discriminator_loss:0.9174
#
# EPOCH[4] - STEP[190]
# Generator_loss:2.3109
# L1_loss:0.1743
# Discriminator_loss:1.0617
#
# EPOCH[4] - STEP[200]
# Generator_loss:1.0865
# L1_loss:0.2399
# Discriminator_loss:0.5869
#
# EPOCH[4] - STEP[210]
# Generator_loss:1.7401
# L1_loss:0.2109
# Discriminator_loss:0.6145
#
# EPOCH[4] - STEP[220]
# Generator_loss:1.9081
# L1_loss:0.2132
# Discriminator_loss:0.5175
#
# EPOCH[4] - STEP[230]
# Generator_loss:2.8914
# L1_loss:0.2021
# Discriminator_loss:0.6606
#
# EPOCH[4] - STEP[240]
# Generator_loss:1.4150
# L1_loss:0.1835
# Discriminator_loss:0.6564
#
# EPOCH[4] - STEP[250]
# Generator_loss:1.0040
# L1_loss:0.1841
# Discriminator_loss:0.7790
#
# EPOCH[5] - STEP[10]
# Generator_loss:1.9023
# L1_loss:0.1747
# Discriminator_loss:1.3364
#
# EPOCH[5] - STEP[20]
# Generator_loss:0.3881
# L1_loss:0.1764
# Discriminator_loss:1.3190
#
# EPOCH[5] - STEP[30]
# Generator_loss:2.1993
# L1_loss:0.1956
# Discriminator_loss:0.4651
#
# EPOCH[5] - STEP[40]
# Generator_loss:0.9471
# L1_loss:0.1816
# Discriminator_loss:0.7557
#
# EPOCH[5] - STEP[50]
# Generator_loss:0.2485
# L1_loss:0.1788
# Discriminator_loss:1.9544
#
# EPOCH[5] - STEP[60]
# Generator_loss:1.8518
# L1_loss:0.1767
# Discriminator_loss:0.5012
#
# EPOCH[5] - STEP[70]
# Generator_loss:0.7640
# L1_loss:0.2396
# Discriminator_loss:0.9796
#
# EPOCH[5] - STEP[80]
# Generator_loss:2.6990
# L1_loss:0.2203
# Discriminator_loss:0.2850
#
# EPOCH[5] - STEP[90]
# Generator_loss:0.5991
# L1_loss:0.1851
# Discriminator_loss:1.0280
#
# EPOCH[5] - STEP[100]
# Generator_loss:2.2614
# L1_loss:0.1870
# Discriminator_loss:0.7733
#
# EPOCH[5] - STEP[110]
# Generator_loss:2.5582
# L1_loss:0.1791
# Discriminator_loss:0.8371
#
# EPOCH[5] - STEP[120]
# Generator_loss:1.5049
# L1_loss:0.2055
# Discriminator_loss:0.8800
#
# EPOCH[5] - STEP[130]
# Generator_loss:2.7299
# L1_loss:0.1815
# Discriminator_loss:1.1590
#
# EPOCH[5] - STEP[140]
# Generator_loss:2.4094
# L1_loss:0.2132
# Discriminator_loss:0.3766
#
# EPOCH[5] - STEP[150]
# Generator_loss:1.8691
# L1_loss:0.1814
# Discriminator_loss:0.3787
#
# EPOCH[5] - STEP[160]
# Generator_loss:1.7300
# L1_loss:0.2243
# Discriminator_loss:0.6542
#
# EPOCH[5] - STEP[170]
# Generator_loss:0.4760
# L1_loss:0.1901
# Discriminator_loss:1.3829
#
# EPOCH[5] - STEP[180]
# Generator_loss:1.7083
# L1_loss:0.2144
# Discriminator_loss:0.3517
#
# EPOCH[5] - STEP[190]
# Generator_loss:0.5547
# L1_loss:0.1874
# Discriminator_loss:1.2063
#
# EPOCH[5] - STEP[200]
# Generator_loss:1.1596
# L1_loss:0.2021
# Discriminator_loss:0.5662
#
# EPOCH[5] - STEP[210]
# Generator_loss:0.6388
# L1_loss:0.1694
# Discriminator_loss:1.3852
#
# EPOCH[5] - STEP[220]
# Generator_loss:2.3617
# L1_loss:0.2115
# Discriminator_loss:0.6019
#
# EPOCH[5] - STEP[230]
# Generator_loss:0.7334
# L1_loss:0.1708
# Discriminator_loss:1.2263
#
# EPOCH[5] - STEP[240]
# Generator_loss:1.0111
# L1_loss:0.2149
# Discriminator_loss:0.7746
#
# EPOCH[5] - STEP[250]
# Generator_loss:2.0456
# L1_loss:0.1977
# Discriminator_loss:0.5924
#
# EPOCH[6] - STEP[10]
# Generator_loss:1.5546
# L1_loss:0.1925
# Discriminator_loss:0.7397
#
# EPOCH[6] - STEP[20]
# Generator_loss:1.2882
# L1_loss:0.1864
# Discriminator_loss:0.6208
#
# EPOCH[6] - STEP[30]
# Generator_loss:1.6434
# L1_loss:0.1644
# Discriminator_loss:1.1266
#
# EPOCH[6] - STEP[40]
# Generator_loss:1.9696
# L1_loss:0.1714
# Discriminator_loss:0.8008
#
# EPOCH[6] - STEP[50]
# Generator_loss:2.3155
# L1_loss:0.2033
# Discriminator_loss:0.3868
#
# EPOCH[6] - STEP[60]
# Generator_loss:1.3934
# L1_loss:0.1869
# Discriminator_loss:0.5880
#
# EPOCH[6] - STEP[70]
# Generator_loss:1.5243
# L1_loss:0.1816
# Discriminator_loss:0.6383
#
# EPOCH[6] - STEP[80]
# Generator_loss:1.1014
# L1_loss:0.1918
# Discriminator_loss:1.9133
#
# EPOCH[6] - STEP[90]
# Generator_loss:2.9121
# L1_loss:0.1930
# Discriminator_loss:0.2065
#
# EPOCH[6] - STEP[100]
# Generator_loss:1.8040
# L1_loss:0.1788
# Discriminator_loss:0.4896
#
# EPOCH[6] - STEP[110]
# Generator_loss:1.3403
# L1_loss:0.2031
# Discriminator_loss:0.5026
#
# EPOCH[6] - STEP[120]
# Generator_loss:0.5206
# L1_loss:0.1628
# Discriminator_loss:1.3624
#
# EPOCH[6] - STEP[130]
# Generator_loss:2.5616
# L1_loss:0.2016
# Discriminator_loss:0.2062
#
# EPOCH[6] - STEP[140]
# Generator_loss:1.1661
# L1_loss:0.1606
# Discriminator_loss:0.7447
#
# EPOCH[6] - STEP[150]
# Generator_loss:1.4584
# L1_loss:0.1528
# Discriminator_loss:0.5170
#
# EPOCH[6] - STEP[160]
# Generator_loss:1.5031
# L1_loss:0.1781
# Discriminator_loss:0.5815
#
# EPOCH[6] - STEP[170]
# Generator_loss:1.2111
# L1_loss:0.1956
# Discriminator_loss:0.6074
#
# EPOCH[6] - STEP[180]
# Generator_loss:1.9249
# L1_loss:0.1731
# Discriminator_loss:0.7023
#
# EPOCH[6] - STEP[190]
# Generator_loss:1.8361
# L1_loss:0.1744
# Discriminator_loss:0.5870
#
# EPOCH[6] - STEP[200]
# Generator_loss:1.2817
# L1_loss:0.1756
# Discriminator_loss:0.8383
#
# EPOCH[6] - STEP[210]
# Generator_loss:1.4195
# L1_loss:0.2057
# Discriminator_loss:0.8336
#
# EPOCH[6] - STEP[220]
# Generator_loss:0.7438
# L1_loss:0.2637
# Discriminator_loss:0.9324
#
# EPOCH[6] - STEP[230]
# Generator_loss:1.0112
# L1_loss:0.1905
# Discriminator_loss:0.6211
#
# EPOCH[6] - STEP[240]
# Generator_loss:1.2644
# L1_loss:0.1720
# Discriminator_loss:0.7887
#
# EPOCH[6] - STEP[250]
# Generator_loss:1.9809
# L1_loss:0.2043
# Discriminator_loss:0.5351
#
# EPOCH[7] - STEP[10]
# Generator_loss:0.7557
# L1_loss:0.1964
# Discriminator_loss:0.7702
#
# EPOCH[7] - STEP[20]
# Generator_loss:1.5687
# L1_loss:0.1716
# Discriminator_loss:0.8123
#
# EPOCH[7] - STEP[30]
# Generator_loss:2.6595
# L1_loss:0.1629
# Discriminator_loss:0.3617
#
# EPOCH[7] - STEP[40]
# Generator_loss:2.0737
# L1_loss:0.2117
# Discriminator_loss:0.3672
#
# EPOCH[7] - STEP[50]
# Generator_loss:2.3169
# L1_loss:0.1546
# Discriminator_loss:0.7619
#
# EPOCH[7] - STEP[60]
# Generator_loss:1.6913
# L1_loss:0.1691
# Discriminator_loss:0.8528
#
# EPOCH[7] - STEP[70]
# Generator_loss:0.2950
# L1_loss:0.1892
# Discriminator_loss:1.8869
#
# EPOCH[7] - STEP[80]
# Generator_loss:0.7351
# L1_loss:0.1911
# Discriminator_loss:0.9342
#
# EPOCH[7] - STEP[90]
# Generator_loss:2.4182
# L1_loss:0.1749
# Discriminator_loss:0.7676
#
# EPOCH[7] - STEP[100]
# Generator_loss:0.4712
# L1_loss:0.1935
# Discriminator_loss:1.3474
#
# EPOCH[7] - STEP[110]
# Generator_loss:2.1826
# L1_loss:0.1443
# Discriminator_loss:0.7729
#
# EPOCH[7] - STEP[120]
# Generator_loss:3.2488
# L1_loss:0.1503
# Discriminator_loss:1.2107
#
# EPOCH[7] - STEP[130]
# Generator_loss:1.9322
# L1_loss:0.1858
# Discriminator_loss:0.6010
#
# EPOCH[7] - STEP[140]
# Generator_loss:2.4431
# L1_loss:0.2092
# Discriminator_loss:0.6335
#
# EPOCH[7] - STEP[150]
# Generator_loss:0.9842
# L1_loss:0.1622
# Discriminator_loss:0.8221
#
# EPOCH[7] - STEP[160]
# Generator_loss:1.4579
# L1_loss:0.1844
# Discriminator_loss:0.5828
#
# EPOCH[7] - STEP[170]
# Generator_loss:2.1695
# L1_loss:0.1981
# Discriminator_loss:1.0297
#
# EPOCH[7] - STEP[180]
# Generator_loss:4.0070
# L1_loss:0.1572
# Discriminator_loss:1.2834
#
# EPOCH[7] - STEP[190]
# Generator_loss:3.2436
# L1_loss:0.2000
# Discriminator_loss:1.8268
#
# EPOCH[7] - STEP[200]
# Generator_loss:2.4797
# L1_loss:0.1855
# Discriminator_loss:0.9009
#
# EPOCH[7] - STEP[210]
# Generator_loss:2.4072
# L1_loss:0.1904
# Discriminator_loss:0.8540
#
# EPOCH[7] - STEP[220]
# Generator_loss:2.6715
# L1_loss:0.1993
# Discriminator_loss:0.5973
#
# EPOCH[7] - STEP[230]
# Generator_loss:1.1212
# L1_loss:0.1983
# Discriminator_loss:0.7099
#
# EPOCH[7] - STEP[240]
# Generator_loss:3.0645
# L1_loss:0.2108
# Discriminator_loss:0.7266
#
# EPOCH[7] - STEP[250]
# Generator_loss:1.0923
# L1_loss:0.1898
# Discriminator_loss:0.5971
#
# EPOCH[8] - STEP[10]
# Generator_loss:1.9836
# L1_loss:0.1625
# Discriminator_loss:0.8791
#
# EPOCH[8] - STEP[20]
# Generator_loss:0.4258
# L1_loss:0.1614
# Discriminator_loss:1.3802
#
# EPOCH[8] - STEP[30]
# Generator_loss:2.2210
# L1_loss:0.2052
# Discriminator_loss:0.9428
#
# EPOCH[8] - STEP[40]
# Generator_loss:0.7717
# L1_loss:0.1927
# Discriminator_loss:0.9129
#
# EPOCH[8] - STEP[50]
# Generator_loss:0.9729
# L1_loss:0.1907
# Discriminator_loss:0.5876
#
# EPOCH[8] - STEP[60]
# Generator_loss:1.9098
# L1_loss:0.1881
# Discriminator_loss:0.4243
#
# EPOCH[8] - STEP[70]
# Generator_loss:1.9813
# L1_loss:0.1868
# Discriminator_loss:0.7371
#
# EPOCH[8] - STEP[80]
# Generator_loss:2.1297
# L1_loss:0.1774
# Discriminator_loss:0.4991
#
# EPOCH[8] - STEP[90]
# Generator_loss:1.7467
# L1_loss:0.1706
# Discriminator_loss:0.5168
#
# EPOCH[8] - STEP[100]
# Generator_loss:1.3357
# L1_loss:0.1682
# Discriminator_loss:0.6914
#
# EPOCH[8] - STEP[110]
# Generator_loss:2.1019
# L1_loss:0.1721
# Discriminator_loss:0.4602
#
# EPOCH[8] - STEP[120]
# Generator_loss:2.5822
# L1_loss:0.2034
# Discriminator_loss:0.5037
#
# EPOCH[8] - STEP[130]
# Generator_loss:2.0323
# L1_loss:0.1858
# Discriminator_loss:1.1133
#
# EPOCH[8] - STEP[140]
# Generator_loss:2.0768
# L1_loss:0.1762
# Discriminator_loss:1.1866
#
# EPOCH[8] - STEP[150]
# Generator_loss:1.7726
# L1_loss:0.1663
# Discriminator_loss:0.6155
#
# EPOCH[8] - STEP[160]
# Generator_loss:1.0179
# L1_loss:0.1879
# Discriminator_loss:0.7968
#
# EPOCH[8] - STEP[170]
# Generator_loss:1.2825
# L1_loss:0.1932
# Discriminator_loss:0.7863
#
# EPOCH[8] - STEP[180]
# Generator_loss:3.2963
# L1_loss:0.1733
# Discriminator_loss:1.0724
#
# EPOCH[8] - STEP[190]
# Generator_loss:2.6130
# L1_loss:0.1428
# Discriminator_loss:2.1518
#
# EPOCH[8] - STEP[200]
# Generator_loss:1.5659
# L1_loss:0.2193
# Discriminator_loss:0.4920
#
# EPOCH[8] - STEP[210]
# Generator_loss:0.9452
# L1_loss:0.1641
# Discriminator_loss:0.8514
#
# EPOCH[8] - STEP[220]
# Generator_loss:2.9513
# L1_loss:0.1648
# Discriminator_loss:1.3238
#
# EPOCH[8] - STEP[230]
# Generator_loss:2.5921
# L1_loss:0.1907
# Discriminator_loss:0.8221
#
# EPOCH[8] - STEP[240]
# Generator_loss:2.5949
# L1_loss:0.1764
# Discriminator_loss:0.6679
#
# EPOCH[8] - STEP[250]
# Generator_loss:1.3241
# L1_loss:0.1788
# Discriminator_loss:0.5070
#
# EPOCH[9] - STEP[10]
# Generator_loss:1.0100
# L1_loss:0.1672
# Discriminator_loss:0.7652
#
# EPOCH[9] - STEP[20]
# Generator_loss:2.7841
# L1_loss:0.1438
# Discriminator_loss:1.2520
#
# EPOCH[9] - STEP[30]
# Generator_loss:1.9651
# L1_loss:0.1805
# Discriminator_loss:0.4029
#
# EPOCH[9] - STEP[40]
# Generator_loss:1.2095
# L1_loss:0.2118
# Discriminator_loss:0.6443
#
# EPOCH[9] - STEP[50]
# Generator_loss:2.3277
# L1_loss:0.1969
# Discriminator_loss:0.8645
#
# EPOCH[9] - STEP[60]
# Generator_loss:1.4496
# L1_loss:0.1750
# Discriminator_loss:0.9550
#
# EPOCH[9] - STEP[70]
# Generator_loss:2.0327
# L1_loss:0.1682
# Discriminator_loss:1.3211
#
# EPOCH[9] - STEP[80]
# Generator_loss:2.2472
# L1_loss:0.1860
# Discriminator_loss:0.5479
#
# EPOCH[9] - STEP[90]
# Generator_loss:3.1805
# L1_loss:0.1761
# Discriminator_loss:0.4867
#
# EPOCH[9] - STEP[100]
# Generator_loss:2.5118
# L1_loss:0.1617
# Discriminator_loss:0.9069
#
# EPOCH[9] - STEP[110]
# Generator_loss:2.5156
# L1_loss:0.1684
# Discriminator_loss:0.9367
#
# EPOCH[9] - STEP[120]
# Generator_loss:1.3630
# L1_loss:0.1615
# Discriminator_loss:0.6727
#
# EPOCH[9] - STEP[130]
# Generator_loss:2.1524
# L1_loss:0.1888
# Discriminator_loss:0.3063
#
# EPOCH[9] - STEP[140]
# Generator_loss:1.3105
# L1_loss:0.1729
# Discriminator_loss:0.4816
#
# EPOCH[9] - STEP[150]
# Generator_loss:1.1338
# L1_loss:0.2199
# Discriminator_loss:1.1486
#
# EPOCH[9] - STEP[160]
# Generator_loss:1.0321
# L1_loss:0.1808
# Discriminator_loss:0.6908
#
# EPOCH[9] - STEP[170]
# Generator_loss:2.2670
# L1_loss:0.1643
# Discriminator_loss:1.0724
#
# EPOCH[9] - STEP[180]
# Generator_loss:0.1574
# L1_loss:0.1646
# Discriminator_loss:2.2194
#
# EPOCH[9] - STEP[190]
# Generator_loss:1.4096
# L1_loss:0.1758
# Discriminator_loss:0.8584
#
# EPOCH[9] - STEP[200]
# Generator_loss:2.0271
# L1_loss:0.1810
# Discriminator_loss:0.5884
#
# EPOCH[9] - STEP[210]
# Generator_loss:0.5330
# L1_loss:0.1946
# Discriminator_loss:1.3454
#
# EPOCH[9] - STEP[220]
# Generator_loss:1.8506
# L1_loss:0.1841
# Discriminator_loss:0.6935
#
# EPOCH[9] - STEP[230]
# Generator_loss:2.8265
# L1_loss:0.1926
# Discriminator_loss:0.2500
#
# EPOCH[9] - STEP[240]
# Generator_loss:2.5844
# L1_loss:0.1630
# Discriminator_loss:0.4333
#
# EPOCH[9] - STEP[250]
# Generator_loss:2.9162
# L1_loss:0.1773
# Discriminator_loss:1.4487
#
# EPOCH[10] - STEP[10]
# Generator_loss:1.7643
# L1_loss:0.1652
# Discriminator_loss:0.5690
#
# EPOCH[10] - STEP[20]
# Generator_loss:0.5989
# L1_loss:0.1542
# Discriminator_loss:1.3559
#
# EPOCH[10] - STEP[30]
# Generator_loss:1.3445
# L1_loss:0.1595
# Discriminator_loss:0.6700
#
# EPOCH[10] - STEP[40]
# Generator_loss:2.1689
# L1_loss:0.2084
# Discriminator_loss:0.5424
#
# EPOCH[10] - STEP[50]
# Generator_loss:0.2074
# L1_loss:0.2105
# Discriminator_loss:2.1814
#
# EPOCH[10] - STEP[60]
# Generator_loss:2.4111
# L1_loss:0.1464
# Discriminator_loss:1.1482
#
# EPOCH[10] - STEP[70]
# Generator_loss:0.5611
# L1_loss:0.2014
# Discriminator_loss:1.0479
#
# EPOCH[10] - STEP[80]
# Generator_loss:1.7010
# L1_loss:0.1475
# Discriminator_loss:0.8176
#
# EPOCH[10] - STEP[90]
# Generator_loss:3.2552
# L1_loss:0.1761
# Discriminator_loss:1.0071
#
# EPOCH[10] - STEP[100]
# Generator_loss:1.5583
# L1_loss:0.1654
# Discriminator_loss:0.3679
#
# EPOCH[10] - STEP[110]
# Generator_loss:2.3401
# L1_loss:0.1999
# Discriminator_loss:0.4359
#
# EPOCH[10] - STEP[120]
# Generator_loss:2.1489
# L1_loss:0.1408
# Discriminator_loss:0.4733
#
# EPOCH[10] - STEP[130]
# Generator_loss:0.9794
# L1_loss:0.1718
# Discriminator_loss:0.7253
#
# EPOCH[10] - STEP[140]
# Generator_loss:1.9085
# L1_loss:0.1664
# Discriminator_loss:0.3498
#
# EPOCH[10] - STEP[150]
# Generator_loss:0.2770
# L1_loss:0.2116
# Discriminator_loss:1.7286
#
# EPOCH[10] - STEP[160]
# Generator_loss:1.6211
# L1_loss:0.1660
# Discriminator_loss:0.8892
#
# EPOCH[10] - STEP[170]
# Generator_loss:0.4225
# L1_loss:0.1825
# Discriminator_loss:1.8320
#
# EPOCH[10] - STEP[180]
# Generator_loss:2.9292
# L1_loss:0.1672
# Discriminator_loss:0.7836
#
# EPOCH[10] - STEP[190]
# Generator_loss:1.4915
# L1_loss:0.1557
# Discriminator_loss:0.5253
#
# EPOCH[10] - STEP[200]
# Generator_loss:3.0274
# L1_loss:0.1749
# Discriminator_loss:0.3834
#
# EPOCH[10] - STEP[210]
# Generator_loss:0.3787
# L1_loss:0.1451
# Discriminator_loss:1.5478
#
# EPOCH[10] - STEP[220]
# Generator_loss:1.2877
# L1_loss:0.1582
# Discriminator_loss:2.2335
#
# EPOCH[10] - STEP[230]
# Generator_loss:2.8722
# L1_loss:0.1414
# Discriminator_loss:1.6503
#
# EPOCH[10] - STEP[240]
# Generator_loss:0.9898
# L1_loss:0.2242
# Discriminator_loss:0.6027
#
# EPOCH[10] - STEP[250]
# Generator_loss:0.3461
# L1_loss:0.1673
# Discriminator_loss:1.6863

# %%
# loss 값 시각화
plt.figure(figsize=(16,10))

plt.subplot(311)
plt.plot(history['gen_loss'])
plt.title('Generator Loss')

plt.subplot(312)
plt.plot(history['l1_loss'])
plt.title('L1 Loss')

plt.subplot(313)
plt.plot(history['disc_loss'])
plt.title('Discriminator Loss')

plt.show()

# %%
# 이미지 denormalize하여 확인하기
for val_image in os.listdir(val_path):
    f = os.path.join(val_path, val_image)
    input_image, real_image = load_img(f)

    pred = generator(tf.expand_dims(input_image, 0))
    pred = denormalize(pred)

    plt.figure(figsize=(20,10))
    plt.subplot(1,3,1); plt.imshow(denormalize(input_image)); plt.title('Input Image', fontsize=15)
    plt.subplot(1,3,2); plt.imshow(pred[0]); plt.title('Predicted Image', fontsize=20)
    plt.subplot(1,3,3); plt.imshow(denormalize(real_image)); plt.title('Ground Truth', fontsize=15)
